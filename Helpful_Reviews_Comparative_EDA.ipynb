# %% [markdown]
# # Helpful Reviews
#
# ### Comparative Exploratory Data Analysis
#
# ### Corey J Wade, WM^3

# %% [markdown]
# ## Introduction

# %% [markdown]
# This Jupyter Notebook will present comparative exploratory data analysis of an Amazon Book Reviews dataset courtesy of Julian McAuley, UCSD:
#
# http://jmcauley.ucsd.edu/data/amazon/
#
# The purpose of this dataset is to select between several subsets of the dataframe based on Total_Votes.

# %% [markdown]
# ## Open Full Dataset

# %%
# Import standard libraries
import pandas as pd
import numpy as np

# Open DataFrames
df = pd.read_csv('df.csv')
df_5 = pd.read_csv('df_5.csv')
df_10 = pd.read_csv('df_10.csv')

# %%
# View Full DataFrame
df.head()
# Out:
#    Unnamed: 0  index        asin helpful  overall  \
# 0           0      1  000100039X  [0, 2]      5.0
# 1           1      4  000100039X  [7, 9]      5.0
# 2           2     14  000100039X  [1, 1]      5.0
# 3           3     15  000100039X  [1, 1]      5.0
# 4           4     17  000100039X  [3, 5]      5.0
#
#                                           reviewText   reviewTime  \
# 0  This is one my must have books. It is a master...  12 11, 2003
# 1  A timeless classic.  It is a very demanding an...   10 7, 2002
# 2  I discovered The Prophet fifty years ago in co...  01 23, 2013
# 3  Can't say enough about Kahlil Gibran's work am...  06 27, 2012
# 4  Anything I've read by Gibran is, in my mind, f...  11 16, 2005
#
#        reviewerID                                     reviewerName  \
# 0  A2S166WSCFIFP5  adead_poet@hotmail.com "adead_poet@hotmail.com"
# 1  A2XQ5LZHTD4AFT                                         Alaturka
# 2  A19N3FCQCLJYUA                                  Amazon Customer
# 3  A3FFNE1DR5SI1W                                       A. Morelli
# 4  A2X4HE21JTAL98                                      Antiquarian
#
#                                  summary    ...     Total_Votes  \
# 0                           close to god    ...               2
# 1                          A Modern Rumi    ...               9
# 2  A book everyone &#34;should&#34; read    ...               1
# 3        phenomenal piece of literature!    ...               1
# 4                               Flawless    ...               5
#
#    Helpful_Percentage  Review_Length  Sentence_Length  Word_Length  \
# 0            0.000000            268         9.800000     4.306122
# 1            0.777778            813        13.818182     4.260000
# 2            1.000000            870        18.111111     4.148148
# 3            1.000000            427        11.833333     4.845070
# 4            0.600000            485        16.000000     4.775000
#
#    Helpful_Rating  Helpful_Votes_Scaled  Helpful_Percentage_Book_Score  Badge  \
# 0        0.010826              0.000000                       0.541325      1
# 1        0.797675              0.836220                       0.545366      4
# 2        0.753353              0.434560                       0.541903      4
# 3        0.753353              0.434560                       0.541903      4
# 4        0.631986              0.678869                       0.543059      3
#
#    Helpful?
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
#
# [5 rows x 22 columns]

# %%
# View Full DataFrame
df_5.head()
# Out:
#    Unnamed: 0  index        asin   helpful  overall  \
# 0           1      4  000100039X    [7, 9]      5.0
# 1           4     17  000100039X    [3, 5]      5.0
# 2           9     23  000100039X    [2, 9]      2.0
# 3          10     25  000100039X    [5, 6]      5.0
# 4          14     34  000100039X  [81, 92]      5.0
#
#                                           reviewText   reviewTime  \
# 0  A timeless classic.  It is a very demanding an...   10 7, 2002
# 1  Anything I've read by Gibran is, in my mind, f...  11 16, 2005
# 2  I read this about a year ago and can't recall ...  03 21, 2008
# 3  I first read The Prophet by Kahlil Gibran over...  03 12, 2012
# 4  This is one of the first (literary) books I re...  06 24, 2000
#
#        reviewerID                             reviewerName  \
# 0  A2XQ5LZHTD4AFT                                 Alaturka
# 1  A2X4HE21JTAL98                              Antiquarian
# 2  A1KQ80Y692CDOI                                    Atown
# 3   AF7CSSGV93RXN  A. William Benitez "A. William Benitez"
# 4  A1NPNGWBVD9AK3                      Bruce Kendall "BEK"
#
#                summary    ...     Total_Votes  Helpful_Percentage  \
# 0        A Modern Rumi    ...               9            0.777778
# 1             Flawless    ...               5            0.600000
# 2             Eloquent    ...               9            0.222222
# 3  A Great Little Gift    ...               6            0.833333
# 4        Simple Wisdom    ...              92            0.880435
#
#    Review_Length  Sentence_Length  Word_Length  Helpful_Rating  \
# 0            813        13.818182     4.260000        0.797675
# 1            485        16.000000     4.775000        0.631986
# 2            711        16.750000     4.194030        0.392289
# 3            432        15.200000     4.618421        0.805534
# 4           1542        15.000000     4.258865        0.921901
#
#    Helpful_Votes_Scaled  Helpful_Percentage_Book_Score  Badge  Helpful?
# 0              0.836220                       0.545366      4         1
# 1              0.678869                       0.543059      3         0
# 2              0.611893                       0.542481      2         0
# 3              0.780913                       0.544213      4         1
# 4              0.993132                       0.587119      4         1
#
# [5 rows x 22 columns]

# %%
# View Full DataFrame
df_10.head()
# Out:
#    Unnamed: 0  index        asin   helpful  overall  \
# 0          14     34  000100039X  [81, 92]      5.0
# 1          18     43  000100039X   [8, 10]      5.0
# 2          19     46  000100039X   [8, 10]      5.0
# 3          35     75  000100039X  [10, 12]      5.0
# 4          36     76  000100039X   [0, 13]      2.0
#
#                                           reviewText   reviewTime  \
# 0  This is one of the first (literary) books I re...  06 24, 2000
# 1  The Prophet is Kahlil Gibran's best known work...  10 27, 2009
# 2  Gibran Khalil Gibran was born in 1883 in what ...  01 10, 2006
# 3  Certainly the words are of Kahlil Gibran, but ...   11 5, 2001
# 4  I evidently misread the writeup, I thought it ...   05 3, 2009
#
#        reviewerID              reviewerName  \
# 0  A1NPNGWBVD9AK3       Bruce Kendall "BEK"
# 1  A3IS4WGMFR4X65  Colin Lewis "WisdomNote"
# 2   AWLFVCT9128JV         Dave_42 "Dave_42"
# 3  A1SP45I55GQIIE            harendra desai
# 4  A2ZB1G1KUE6OS6                    Harley
#
#                              summary    ...     Total_Votes  \
# 0                      Simple Wisdom    ...              92
# 1  The most loving book ever written    ...              10
# 2                The Lessons Of Life    ...              10
# 3   divine wisdom in  earthly words.    ...              12
# 4                Unexpected purchase    ...              13
#
#    Helpful_Percentage  Review_Length  Sentence_Length  Word_Length  \
# 0            0.880435           1542        15.000000     4.258865
# 1            0.800000           2294        22.705882     4.883289
# 2            0.800000            712        19.428571     4.103704
# 3            0.833333            700        21.000000     4.675000
# 4            0.000000            178        11.666667     3.885714
#
#    Helpful_Rating  Helpful_Votes_Scaled  Helpful_Percentage_Book_Score  Badge  \
# 0        0.921901              0.993132                       0.587119      4
# 1        0.816553              0.851511                       0.545942      4
# 2        0.816553              0.851511                       0.545942      4
# 3        0.851313              0.889774                       0.547093      4
# 4        0.010826              0.000000                       0.541325      1
#
#    Helpful?
# 0         1
# 1         1
# 2         1
# 3         1
# 4         0
#
# [5 rows x 22 columns]

# %%
# Delete extraneous column from all dataframes
del df['Unnamed: 0']
del df_5['Unnamed: 0']
del df_10['Unnamed: 0']

# %%
df.describe()
# Out:
#               index       overall  unixReviewTime  Helpful_Votes  \
# count  4.756338e+06  4.756338e+06    4.756338e+06   4.756338e+06
# mean   4.281655e+06  4.101044e+00    1.284901e+09   5.625667e+00
# std    2.542118e+06  1.202299e+00    1.174243e+08   2.663631e+01
# min    1.000000e+00  1.000000e+00    8.356608e+08   0.000000e+00
# 25%    2.084784e+06  4.000000e+00    1.221523e+09   1.000000e+00
# 50%    4.202102e+06  5.000000e+00    1.333843e+09   2.000000e+00
# 75%    6.506252e+06  5.000000e+00    1.373414e+09   4.000000e+00
# max    8.898040e+06  5.000000e+00    1.406074e+09   2.331100e+04
#
#         Total_Votes  Helpful_Percentage  Review_Length  Sentence_Length  \
# count  4.756338e+06        4.756338e+06   4.756338e+06     4.756338e+06
# mean   7.575643e+00        7.348979e-01   1.036185e+03     1.623846e+01
# std    3.052654e+01        3.426306e-01   1.182085e+03     6.536170e+00
# min    1.000000e+00        0.000000e+00   1.000000e+00     5.000000e-02
# 25%    1.000000e+00        5.000000e-01   2.820000e+02     1.196154e+01
# 50%    2.000000e+00        9.333333e-01   6.410000e+02     1.550000e+01
# 75%    6.000000e+00        1.000000e+00   1.372000e+03     1.960000e+01
# max    2.421200e+04        1.000000e+00   3.265800e+04     5.910000e+02
#
#         Word_Length  Helpful_Rating  Helpful_Votes_Scaled  \
# count  4.756338e+06    4.756338e+06          4.756338e+06
# mean   4.454504e+00    6.572302e-01          5.572892e-01
# std    4.557439e-01    2.709052e-01          2.661728e-01
# min    0.000000e+00    1.082650e-02          0.000000e+00
# 25%    4.185185e+00    5.505382e-01          4.345601e-01
# 50%    4.443536e+00    7.534652e-01          6.118928e-01
# 75%    4.709677e+00    8.284249e-01          7.588114e-01
# max    2.559412e+02    9.994812e-01          1.000000e+00
#
#        Helpful_Percentage_Book_Score         Badge      Helpful?
# count                   4.756338e+06  4.756338e+06  4.756338e+06
# mean                    5.812982e-01  3.393917e+00  6.229618e-01
# std                     6.996599e-02  1.026452e+00  4.846447e-01
# min                     5.413249e-01  1.000000e+00  0.000000e+00
# 25%                     5.432249e-01  3.000000e+00  0.000000e+00
# 50%                     5.516115e-01  4.000000e+00  1.000000e+00
# 75%                     5.851192e-01  4.000000e+00  1.000000e+00
# max                     1.000000e+00  6.000000e+00  1.000000e+00

# %%
df_5.describe()
# Out:
#               index       overall  unixReviewTime  Helpful_Votes  \
# count  1.506724e+06  1.506724e+06    1.506724e+06   1.506724e+06
# mean   3.750760e+06  3.757796e+00    1.216341e+09   1.488788e+01
# std    2.353255e+06  1.438525e+00    1.286098e+08   4.595768e+01
# min    4.000000e+00  1.000000e+00    8.356608e+08   0.000000e+00
# 25%    1.792852e+06  3.000000e+00    1.121558e+09   5.000000e+00
# 50%    3.516868e+06  4.000000e+00    1.231546e+09   7.000000e+00
# 75%    5.593581e+06  5.000000e+00    1.332202e+09   1.400000e+01
# max    8.898029e+06  5.000000e+00    1.405987e+09   2.331100e+04
#
#         Total_Votes  Helpful_Percentage  Review_Length  Sentence_Length  \
# count  1.506724e+06        1.506724e+06   1.506724e+06     1.506724e+06
# mean   1.995493e+01        7.335015e-01   1.404853e+03     1.754614e+01
# std    5.210724e+01        2.571116e-01   1.433892e+03     6.380482e+00
# min    5.000000e+00        0.000000e+00   3.000000e+00     3.157895e-01
# 25%    6.000000e+00        6.000000e-01   4.950000e+02     1.342857e+01
# 50%    1.000000e+01        8.000000e-01   9.880000e+02     1.685714e+01
# 75%    1.900000e+01        9.411765e-01   1.830000e+03     2.075610e+01
# max    2.421200e+04        1.000000e+00   3.265800e+04     5.910000e+02
#
#         Word_Length  Helpful_Rating  Helpful_Votes_Scaled  \
# count  1.506724e+06    1.506724e+06          1.506724e+06
# mean   4.552855e+00    7.679705e-01          8.214102e-01
# std    3.960761e-01    1.929134e-01          1.526331e-01
# min    1.000000e+00    1.082650e-02          0.000000e+00
# 25%    4.296296e+00    6.785326e-01          7.809132e-01
# 50%    4.541781e+00    8.169207e-01          8.362199e-01
# 75%    4.797030e+00    9.153121e-01          9.187989e-01
# max    5.266667e+01    9.994812e-01          1.000000e+00
#
#        Helpful_Percentage_Book_Score         Badge      Helpful?
# count                   1.506724e+06  1.506724e+06  1.506724e+06
# mean                    6.108691e-01  3.688668e+00  6.545412e-01
# std                     8.714893e-02  7.652795e-01  4.755178e-01
# min                     5.413249e-01  1.000000e+00  0.000000e+00
# 25%                     5.495654e-01  3.000000e+00  0.000000e+00
# 50%                     5.733642e-01  4.000000e+00  1.000000e+00
# 75%                     6.414353e-01  4.000000e+00  1.000000e+00
# max                     1.000000e+00  6.000000e+00  1.000000e+00

# %%
df_10.describe()
# Out:
#               index        overall  unixReviewTime  Helpful_Votes  \
# count  7.879810e+05  787981.000000    7.879810e+05  787981.000000
# mean   3.652510e+06       3.621601    1.195712e+09      24.140927
# std    2.274325e+06       1.526728    1.288175e+08      62.092757
# min    3.400000e+01       1.000000    8.484480e+08       0.000000
# 25%    1.770411e+06       2.000000    1.099699e+09       9.000000
# 50%    3.476225e+06       4.000000    1.196726e+09      13.000000
# 75%    5.315390e+06       5.000000    1.312330e+09      24.000000
# max    8.898014e+06       5.000000    1.405987e+09   23311.000000
#
#          Total_Votes  Helpful_Percentage  Review_Length  Sentence_Length  \
# count  787981.000000       787981.000000  787981.000000    787981.000000
# mean       32.205261            0.740193    1591.897915        17.967505
# std        69.824325            0.254808    1576.932201         6.397815
# min        10.000000            0.000000       4.000000         0.602484
# 25%        13.000000            0.600000     591.000000        13.916667
# 50%        18.000000            0.826087    1145.000000        17.266667
# 75%        32.000000            0.933333    2068.000000        21.142857
# max     24212.000000            1.000000   32658.000000       591.000000
#
#          Word_Length  Helpful_Rating  Helpful_Votes_Scaled  \
# count  787981.000000   787981.000000         787981.000000
# mean        4.594298        0.803397              0.896059
# std         0.391554        0.179388              0.115501
# min         1.000000        0.010826              0.000000
# 25%         4.340741        0.720731              0.878174
# 50%         4.582734        0.865173              0.914399
# 75%         4.835052        0.938157              0.959828
# max        52.666667        0.999481              1.000000
#
#        Helpful_Percentage_Book_Score          Badge       Helpful?
# count                  787981.000000  787981.000000  787981.000000
# mean                        0.627209       3.870117       0.722493
# std                         0.094488       0.785538       0.447769
# min                         0.541325       1.000000       0.000000
# 25%                         0.554355       3.000000       0.000000
# 50%                         0.590519       4.000000       1.000000
# 75%                         0.671623       4.000000       1.000000
# max                         1.000000       6.000000       1.000000

# %% [markdown]
# The distribution of Helpful_Rating changes with each iteration. The more selective the total reviews, the stronger the Helpful_Rating.

# %% [markdown]
# ## Display Histograms

# %% [markdown]
# ### All Rows

# %%
# Show plots inline
# %matplotlib inline

#Import matplotlib
import matplotlib.pyplot as plt

# Create histograms for all numberical columns, set number of bins and size
df.hist(bins=25, figsize=(20,15))

# Show plot
plt.show()

# %%
# Show plots inline
# %matplotlib inline

#Import matplotlib
import matplotlib.pyplot as plt

# Create histograms for all numberical columns, set number of bins and size
df_5.hist(bins=25, figsize=(20,15))

# Show plot
plt.show()

# %%
# Show plots inline
# %matplotlib inline

#Import matplotlib
import matplotlib.pyplot as plt

# Create histograms for all numberical columns, set number of bins and size
df_10.hist(bins=25, figsize=(20,15))

# Show plot
plt.show()

# %% [markdown]
# df_5 and df_10 have similar graphs. The change in distribution of the overall rating and the helpful_rating are interesting. The helpful rating is the smoothest for df_10. My choice going forward will be df_10.

# %% [markdown]
# ## Helpful_Rating

# %% [markdown]
# ### Correlation Matrix

# %%
corr_matrix = df.corr()
corr_matrix['Helpful_Rating'].sort_values(ascending=False)
# Out:
# Helpful_Rating                   1.000000
# Badge                            0.962921
# Helpful_Percentage               0.938691
# Helpful_Votes_Scaled             0.807941
# Helpful?                         0.765614
# Helpful_Percentage_Book_Score    0.338584
# Review_Length                    0.190890
# overall                          0.166213
# Helpful_Votes                    0.153557
# Sentence_Length                  0.123556
# Word_Length                      0.120912
# Total_Votes                      0.114385
# index                            0.043665
# unixReviewTime                  -0.154979
# Name: Helpful_Rating, dtype: float64

# %% [markdown]
# Review_Length, Sentence_Length, Word_Length and overall should all be considered as they had nothing to do with the creation of the Helpful_Rating column.

# %%
corr_matrix = df_10.corr()
corr_matrix['Helpful_Rating'].sort_values(ascending=False)
# Out:
# Helpful_Rating                   1.000000
# Helpful_Percentage               0.979199
# Badge                            0.889888
# Helpful?                         0.829844
# Helpful_Votes_Scaled             0.800840
# overall                          0.469015
# Helpful_Percentage_Book_Score    0.431202
# Helpful_Votes                    0.181842
# Review_Length                    0.173759
# Sentence_Length                  0.146148
# Word_Length                      0.129737
# index                            0.078112
# Total_Votes                      0.062566
# unixReviewTime                  -0.128354
# Name: Helpful_Rating, dtype: float64

# %% [markdown]
# It's surprising that the correlation for overall is nearly 2.5 times as strong in this subset. The other factors are about the same.

# %% [markdown]
# ### Scatter Matrix

# %%
from pandas.plotting import scatter_matrix

attributes = ['Helpful_Rating', 'Review_Length', 'Sentence_Length', 'Word_Length', 'overall']
scatter_matrix(df[attributes], figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1223324a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1210a0128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10fa1fac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126918d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1277e1da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1277e1a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12785b588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12788f0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1278b9fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12299be80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1278ec5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1201c34e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1223a83c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12679b780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127967518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12798de80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1279b6668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1279d5390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10f9ecd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127a16550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x10fa49588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x127a54a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12027eba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10fa71128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126923390>]],
#       dtype=object)

# %%
attributes = ['Helpful_Rating', 'Review_Length', 'Sentence_Length', 'Word_Length', 'overall']
scatter_matrix(df_10[attributes], figsize=(12,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127a7efd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267a2f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267963c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126851a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12671d128>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12671d160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126752e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266e5518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266d9ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267b0278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x184853908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x18487cf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1877af668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126878cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x184a493c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x184a73a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120463128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120cbe7b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120ce5e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124107518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x124130ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1223790b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1278cd7f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x122227e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12226e278>]],
#       dtype=object)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Although df has more data points, df_10 has stronger correlations between the target column and predictor columns and should perform better. This makes sense because more votes should give a more accurate helpful score.
